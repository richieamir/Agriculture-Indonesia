# %% [markdown]
# ### Importing Packages

# %%
import tabula
import pandas as pd
import os

# %% [markdown]
# ## Read production data 2018

# %%
production_2018 = os.listdir('data/production/2018')

# %%
dfs = {}
for plant in production_2018:
    temp = plant.split('.')
    var_name = 'df-' + temp[0]
    
    df = tabula.read_pdf("data/production/2018/{}".format(plant), pages='all')
    df = pd.DataFrame(df[0])
    df = df.drop([0,1,2,3,4])
    df = df.rename(columns={'Unnamed: 1':'Province','Unnamed: 4':'Production','Unnamed: 6':'Production_growth'})
    df = df.loc[:, ~df.columns.str.contains('^Unnamed')]
    df = df.drop(['Tahun'],axis=1)
    df = df.dropna()
    df.reset_index(inplace=True,drop=True)
    dfs[var_name] = df
# Out:
# {'df-cassava-production':                      Province Production Production_growth
#  0              Sumatera Utara    803,403            -18.09
#  1              Sumatera Barat    201,833             -3.48
#  2                        Riau    133,738              7.16
#  3                       Jambi     56,605            -12.23
#  4            Sumatera Selatan    382,043            -29.12
#  5                    Bengkulu     73,491             13.69
#  6                     Lampung  6,683,758             22.61
#  7   Kepulauan Bangka Belitung     59,426            -15.41
#  8              Kepulauan Riau     19,722              1.28
#  9                 DKI Jakarta          -                 -
#  10                 Jawa Barat  1,635,031            -14.01
#  11                Jawa Tengah  3,267,417              4.10
#  12              DI Yogyakarta    859,393            -16.21
#  13                 Jawa Timur  2,551,840            -12.26
#  14                     Banten     72,616             -3.80
#  15                       Bali     92,144             18.19
#  16        Nusa Tenggara Barat     58,021             18.60
#  17        Nusa Tenggara Timur    853,468              3.69
#  18           Kalimantan Barat    147,475              6.06
#  19          Kalimantan Tengah    142,852             48.08
#  20         Kalimantan Selatan     88,974              0.14
#  21           Kalimantan Timur     86,079              0.16
#  22           Kalimantan Utara     44,050              2.73
#  23             Sulawesi Utara     41,651             -6.29
#  24            Sulawesi Tengah     48,405            -10.73
#  25           Sulawesi Selatan    422,601             14.70
#  26          Sulawesi Tenggara    209,159            -13.89
#  27                  Gorontalo      2,781             22.08
#  28             Sulawesi Barat     22,174            -36.03
#  29                     Maluku     85,734            -40.32
#  30               Maluku Utara    122,706             -3.20
#  31                Papua Barat     22,798            111.43
#  32                      Papua     34,173             37.78,
#  'df-corn-production':                      Province Production Production_growth
#  0                        Aceh    347,735            -10.25
#  1              Sumatera Utara  1,757,126              0.91
#  2              Sumatera Barat  1,052,408              6.75
#  3                        Riau     25,723            -16.39
#  4                       Jambi    152,158             54.19
#  5            Sumatera Selatan    935,240              4.81
#  6                    Bengkulu    111,816            -24.49
#  7                     Lampung  2,581,224              2.47
#  8   Kepulauan Bangka Belitung      3,630             14.01
#  9              Kepulauan Riau         77             12.99
#  10                DKI Jakarta          -                 -
#  11                 Jawa Barat  1,550,966              8.85
#  12                Jawa Tengah  3,688,477              3.10
#  13              DI Yogyakarta    314,179              0.77
#  14                 Jawa Timur  6,543,359              3.28
#  15                     Banten    174,334            174.47
#  16                       Bali     51,459             -6.51
#  17        Nusa Tenggara Barat  2,059,222             -3.20
#  18        Nusa Tenggara Timur    859,230              6.10
#  19           Kalimantan Barat    166,826             10.05
#  20          Kalimantan Tengah    158,964            211.37
#  21         Kalimantan Selatan    364,489             27.63
#  22           Kalimantan Timur     88,105             55.67
#  23           Kalimantan Utara      5,977             15.83
#  24             Sulawesi Utara  1,531,241             -6.42
#  25            Sulawesi Tengah    380,650              1.69
#  26           Sulawesi Selatan  2,341,659              0.01
#  27          Sulawesi Tenggara    192,329             11.77
#  28                  Gorontalo  1,619,649              4.36
#  29             Sulawesi Barat    702,339             -3.02
#  30                     Maluku     40,550            175.72
#  31               Maluku Utara    237,778            575.85
#  32                Papua Barat      4,218             96.37
#  33                      Papua     12,476             24.15,
#  'df-green-beans-production':                      Province Production Production_growth
#  0                        Aceh        369            -49.93
#  1              Sumatera Utara      2,350            -18.23
#  2              Sumatera Barat        264             -7.69
#  3                        Riau        434             -3.13
#  4                       Jambi        141            -23.78
#  5            Sumatera Selatan        744            -21.77
#  6                    Bengkulu        344             -1.43
#  7                     Lampung      1,274              0.71
#  8   Kepulauan Bangka Belitung          -                 -
#  9              Kepulauan Riau          3           -100.00
#  10                DKI Jakarta          -                 -
#  11                 Jawa Barat      9,006             -9.79
#  12                Jawa Tengah    112,162             -8.98
#  13              DI Yogyakarta        281             -6.64
#  14                 Jawa Timur     46,925            -10.45
#  15                     Banten        254             14.93
#  16                       Bali        111            -71.76
#  17        Nusa Tenggara Barat     26,434             85.41
#  18        Nusa Tenggara Timur      6,157            -14.86
#  19           Kalimantan Barat      1,261             -7.82
#  20          Kalimantan Tengah         21            -19.05
#  21         Kalimantan Selatan        749             10.80
#  22           Kalimantan Timur        204             20.00
#  23           Kalimantan Utara         89              4.49
#  24             Sulawesi Utara        465            -21.19
#  25            Sulawesi Tengah        585             21.62
#  26           Sulawesi Selatan     22,000              7.44
#  27          Sulawesi Tenggara        777             13.93
#  28                  Gorontalo         26            -50.00
#  29             Sulawesi Barat        480            -31.53
#  30               Maluku Utara        332             -6.21
#  31                Papua Barat         79            -29.11
#  32                      Papua        358             46.12,
#  'df-peanuts-production':                      Province Production Production_growth
#  0              Sumatera Utara      4,323             -1.30
#  1              Sumatera Barat      4,717              9.44
#  2                        Riau      1,058             31.43
#  3                       Jambi      1,488             13.59
#  4            Sumatera Selatan      1,099            -64.70
#  5                    Bengkulu      2,960             53.77
#  6                     Lampung      3,333            -24.27
#  7   Kepulauan Bangka Belitung        201              2.03
#  8                 DKI Jakarta          -                 -
#  9                  Jawa Barat     39,601            -23.03
#  10                Jawa Tengah     94,291              3.35
#  11              DI Yogyakarta    107,376             34.37
#  12                 Jawa Timur    150,180             -1.98
#  13                     Banten      5,348             -6.62
#  14                       Bali      5,993              4.15
#  15        Nusa Tenggara Barat     33,303             -2.98
#  16        Nusa Tenggara Timur     10,682              2.27
#  17           Kalimantan Barat        851             29.33
#  18          Kalimantan Tengah        415             14.33
#  19         Kalimantan Selatan      6,311            -19.78
#  20           Kalimantan Timur      1,003             -0.50
#  21           Kalimantan Utara        194             -4.90
#  22             Sulawesi Utara      2,442            -14.23
#  23            Sulawesi Tengah      3,366             21.65
#  24           Sulawesi Selatan     19,152             18.45
#  25          Sulawesi Tenggara      2,606             -0.42
#  26                  Gorontalo        341            -27.91
#  27             Sulawesi Barat        391              1.56
#  28                     Maluku        834            -43.65
#  29               Maluku Utara      2,185             12.69
#  30                Papua Barat        634             80.63
#  31                      Papua      1,788             33.53,
#  'df-rice-production':                      Province  Production Production_growth
#  0                        Aceh   2,516,221              0.87
#  1              Sumatera Utara   5,423,154              5.59
#  2              Sumatera Barat   2,754,079             -2.49
#  3                        Riau     391,132              6.94
#  4                       Jambi     855,944              9.45
#  5            Sumatera Selatan   5,076,831              2.71
#  6                    Bengkulu     699,531             -4.33
#  7                     Lampung   4,556,378              7.23
#  8   Kepulauan Bangka Belitung      28,310            -23.74
#  9                 DKI Jakarta       4,183             -1.30
#  10                 Jawa Barat  12,494,919              1.59
#  11                Jawa Tengah  11,401,821              0.05
#  12              DI Yogyakarta     878,136             -0.34
#  13                 Jawa Timur  13,000,475             -0.46
#  14                     Banten   2,470,538              2.36
#  15                       Bali     848,698              1.51
#  16        Nusa Tenggara Barat   2,423,285              4.29
#  17        Nusa Tenggara Timur   1,213,760             11.27
#  18           Kalimantan Barat   1,625,355             16.27
#  19          Kalimantan Tengah     783,497              1.50
#  20         Kalimantan Selatan   2,528,593              3.11
#  21           Kalimantan Timur     385,544             -3.64
#  22           Kalimantan Utara      68,793             -9.28
#  23             Sulawesi Utara     887,758             14.42
#  24            Sulawesi Tengah   1,154,907              0.92
#  25           Sulawesi Selatan   6,196,737              2.33
#  26          Sulawesi Tenggara     716,156              0.67
#  27                  Gorontalo     350,256              0.02
#  28             Sulawesi Barat     751,531             12.66
#  29                     Maluku     132,852             26.87
#  30               Maluku Utara     101,054             20.25
#  31                Papua Barat      27,736             -6.03
#  32                      Papua     288,335             11.81,
#  'df-soybean-production':                      Province Production Pertumbuhan
#  0              Sumatera Barat      1,117     1369.74
#  1                        Riau      6,488      479.80
#  2                       Jambi     15,400       40.96
#  3            Sumatera Selatan     14,955       26.82
#  4                    Bengkulu      3,477      741.89
#  5                     Lampung     72,006      797.05
#  6   Kepulauan Bangka Belitung          -           -
#  7              Kepulauan Riau          7      -28.57
#  8                 DKI Jakarta          -           -
#  9                  Jawa Barat    132,099      168.16
#  10                Jawa Tengah    130,525       23.66
#  11              DI Yogyakarta     11,093       28.15
#  12                 Jawa Timur    244,442       21.66
#  13                     Banten     18,446      767.64
#  14                       Bali      3,996      -26.07
#  15        Nusa Tenggara Barat     91,724       63.51
#  16        Nusa Tenggara Timur     16,827      166.97
#  17           Kalimantan Barat      1,260      179.38
#  18          Kalimantan Tengah      1,413      -55.98
#  19         Kalimantan Selatan     24,647      193.10
#  20           Kalimantan Timur        582      -49.87
#  21           Kalimantan Utara      1,144       -0.87
#  22             Sulawesi Utara     50,026      540.87
#  23            Sulawesi Tengah     27,691      458.06
#  24           Sulawesi Selatan     35,824      122.50
#  25          Sulawesi Tenggara      8,007       97.46
#  26                  Gorontalo      3,257      552.71
#  27             Sulawesi Barat     15,091      210.96
#  28                     Maluku        228      -84.03
#  29               Maluku Utara        115      -77.27
#  30                Papua Barat        359      -22.13
#  31                      Papua      1,761      -22.97,
#  'df-sweet-potato-production':                      Province Production Production_growth
#  0                        Aceh      5,714            -16.71
#  1              Sumatera Utara     92,380             -2.23
#  2              Sumatera Barat    112,919            -19.86
#  3                        Riau      4,810             34.51
#  4                       Jambi     34,934            -22.33
#  5            Sumatera Selatan     13,429              4.91
#  6                    Bengkulu     30,193            -26.59
#  7                     Lampung     22,780              6.92
#  8   Kepulauan Bangka Belitung      3,557             -9.67
#  9              Kepulauan Riau      2,474             56.88
#  10                DKI Jakarta          -           #DIV/0!
#  11                 Jawa Barat    547,879             14.66
#  12                Jawa Tengah    145,068             -8.73
#  13              DI Yogyakarta      5,289              4.51
#  14                 Jawa Timur    257,414            -19.91
#  15                     Banten     20,724             -7.70
#  16                       Bali     35,225             -0.86
#  17        Nusa Tenggara Barat     12,857             75.43
#  18        Nusa Tenggara Timur     72,954             -8.40
#  19           Kalimantan Barat     10,308            -10.71
#  20          Kalimantan Tengah      5,554             -9.34
#  21         Kalimantan Selatan     16,752             -0.79
#  22           Kalimantan Timur      9,798            -18.36
#  23           Kalimantan Utara      2,557            -12.91
#  24             Sulawesi Utara     20,851             17.22
#  25            Sulawesi Tengah     15,464            -16.53
#  26           Sulawesi Selatan     52,213            -25.50
#  27          Sulawesi Tenggara     24,753             -3.91
#  28                  Gorontalo       4 15             -8.59
#  29             Sulawesi Barat      8,044             46.71
#  30                     Maluku     35,420            584.58
#  31               Maluku Utara     28,885             -8.66
#  32                Papua Barat     12,385            -30.74
#  33                      Papua    250,245            -18.58}

# %%
    plant = 'banana-production.pdf'
    df = tabula.read_pdf("data/production/2018/{}".format(plant), pages='all')
    df = pd.DataFrame(df[0])
    df = df.drop([0,1,2,3,4])
    df = df.rename(columns={'Unnamed: 1':'Province','Unnamed: 4':'Production','Unnamed: 6':'Production_growth'})
    df = df.loc[:, ~df.columns.str.contains('^Unnamed')]
    df = df.drop(['Tahun'],axis=1)
    df = df.dropna()
    df.reset_index(inplace=True,drop=True)
    dfs[var_name] = df
# Out:
# 2
